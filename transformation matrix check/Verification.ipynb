# %%
from skimage.io import imread
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img0 = imread('00000017.jpg')
plt.imshow(img0)

# %%
img_original = imread('frame00017.jpg')
plt.imshow(img_original)

# %%
plt.imshow(img4)

# %%
img_rotation = cv2.warpAffine(img_original, M, (cols, rows)) 
plt.imshow(img_rotation)

# %%
import cv2
import numpy as np

rows,cols,ch = img_original.shape
M = np.float32([[np.cos(0),-np.sin(np.cos(0.516675)), 73.4995],
                [np.sin(0), np.cos(0.516675), -24.4789]])
dst = cv2.warpAffine(img_original,M, (cols,rows))
plt.imshow(dst)

# %%
import cv2
import numpy as np

rows,cols,ch = img_original.shape
M = np.float32([[np.cos(0.516675),-np.sin(np.cos(0.516675)), 73.4995],
                [np.sin(0.516675), np.cos(0.516675), -24.4789]])
dst = cv2.warpAffine(img_original,M, (cols,rows))
plt.imshow(dst)

# %%
plt.imshow(img0)
